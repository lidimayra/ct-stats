# %%
arquivo = 'pesos.txt'

# %%
conteudo = open(arquivo)

# %%
dados = conteudo.read()

# %%
conteudo.close()

# %%
print(dados)
# Out:
# 48 52 65 65 67 68 70 75 76 77 85 85 85 96 97 98

# %%
lista = str.split(dados)

# %%
print(lista)
# Out:
# ['48', '52', '65', '65', '67', '68', '70', '75', '76', '77', '85', '85', '85', '96', '97', '98']

# %%
inteiros = []

# %%
for elemento in lista:
    inteiros.append(int(elemento))

# %%
print(inteiros)
# Out:
# [48, 52, 65, 65, 67, 68, 70, 75, 76, 77, 85, 85, 85, 96, 97, 98]

# %%
universo_amostral = len(inteiros)

# %%
print(universo_amostral)
# Out:
# 16

# %%
print(inteiros)
# Out:
# [48, 52, 65, 65, 67, 68, 70, 75, 76, 77, 85, 85, 85, 96, 97, 98]

# %%
frequencias = {}
for xi in inteiros:
    if xi not in frequencias:
        frequencias[xi] = 1
    else:
        frequencias[xi] += 1

# %%
print(frequencias)
# Out:
# {96: 1, 65: 2, 98: 1, 67: 1, 68: 1, 70: 1, 97: 1, 75: 1, 76: 1, 77: 1, 48: 1, 52: 1, 85: 3}

# %%
import collections
frequencias = collections.OrderedDict(sorted(frequencias.items()))
print(frequencias)
# Out:
# OrderedDict([(48, 1), (52, 1), (65, 2), (67, 1), (68, 1), (70, 1), (75, 1), (76, 1), (77, 1), (85, 3), (96, 1), (97, 1), (98, 1)])

# %%
xi = list(frequencias.keys())
print(xi)
# Out:
# [48, 52, 65, 67, 68, 70, 75, 76, 77, 85, 96, 97, 98]

# %%
fi = list(frequencias.values())
print(fi)
# Out:
# [1, 1, 2, 1, 1, 1, 1, 1, 1, 3, 1, 1, 1]

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy

y_pos = numpy.arange(len(xi))
plt.bar(y_pos, fi, align='center', alpha=0.5)
plt.xticks(y_pos, xi)
plt.xlim([min(xi)-10, max(xi)+10])
plt.ylim(5)

# pylab.figure(1)
# pylab.plot(xi, fi, 'r--')
# pylab.xlim([min(xi)-10, max(xi)+10])
# pylab.ylim([0,max(fi)+2])
# pylab.title("Pesos")
# pylab.xlabel("xi")
# pylab.ylabel("fi")
# pylab.show()
# Out:
# <img src="data:image/png;base64,...">
# ([<matplotlib.axis.XTick at 0x7f084adcea20>,
# ...
#  <a list of 13 Text xticklabel objects>)
